# %% [markdown]
# # Segmentation of nanoparticles imaged by EM
# ### Guillaume Witz Science IT Support, Bern University

# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage
import ipywidgets as ipw
import selectfile
import nanoparticles as nano
f = selectfile.FileBrowser()

# %% [markdown]
# ## Set image scale

# %%
nm_per_pixel = 0.0001589*1000

# %% [markdown]
# ## Select a folder with images

# %%
f.widget()
# Out:
# GridBox(children=(Button(description='..', style=ButtonStyle()), Button(description='Untitled Folder 1', style…

# %%
radii = nano.analyze_particles(f.path, 20,50, nm_per_pixel, match_quality = 0.15)

# %%
radii.to_csv(f.path+'/radii.csv', sep=',',index = False)
